# %%
import os
import sys
import pandas as pd
import requests
import time

sys.path.append(r"C:\Users\Suyash\Desktop\compound-risk-scoring\scripts")


wallets_df = pd.read_csv(r"C:\Users\Suyash\Desktop\compound-risk-scoring\data\wallets.csv")
wallets_df.columns = ['wallet_id']
wallets = wallets_df['wallet_id'].tolist()

print("Total wallets:", len(wallets))
print("Sample wallets:", wallets[:5])

MORALIS_API_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJub25jZSI6IjUxYTI4NTNlLTUxMGMtNDljMS1hMmY2LTdhZGE0Zjc5OTdjYSIsIm9yZ0lkIjoiNDYxMzYxIiwidXNlcklkIjoiNDc0NjUzIiwidHlwZUlkIjoiMjQ0ZjdjZTktZmFkZS00ODE1LThhNmEtYTg3ZDIzNDk3ZjBhIiwidHlwZSI6IlBST0pFQ1QiLCJpYXQiOjE3NTM0NTA1NzIsImV4cCI6NDkwOTIxMDU3Mn0.HzOe_UR8z8R3s3dJL9jLAZgsASlipuft7Edci6_pkkk"

wallet = "0xfaa0768bde629806739c3a4620656c5d26f44ef2"
chain = "eth"

url = f"https://deep-index.moralis.io/api/v2.2/{wallet}/erc20/transfers?chain={chain}&limit=100"

headers = {
    "accept": "application/json",
    "X-API-Key": MORALIS_API_KEY
}

response = requests.get(url, headers=headers)
data = response.json()

print("Sample transaction data:\n")
print(data)
# Out:
# Total wallets: 103
# Sample wallets: ['0x0039f22efb07a647557c7c5d17854cfd6d489ef3', '0x06b51c6882b27cb05e712185531c1f74996dd988', '0x0795732aacc448030ef374374eaae57d2965c16c', '0x0aaa79f1a86bc8136cd0d1ca0d51964f4e3766f9', '0x0fe383e5abc200055a7f391f94a5f5d1f844b9ae']
# Sample transaction data:
#
# {'page': 0, 'page_size': 100, 'cursor': 'eyJhbGciOiJIUzI1NiJ9..0cag1Q1y9OPnwVuZKk3-futWJeOGsl55RA72efFw2SM', 'result': [{'token_name': 'USD Coin', 'token_symbol': 'USDC', 'token_logo': 'https://logo.moralis.io/0x1_0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48_7f342f7e169e45d4948987ccb93c62a8.png', 'token_decimals': '6', 'from_address_entity': None, 'from_address_entity_logo': None, 'from_address': '0xfaa0768bde629806739c3a4620656c5d26f44ef2', 'from_address_label': None, 'to_address_entity': None, 'to_address_entity_logo': None, 'to_address': '0xf081470f5c6fbccf48cc4e5b82dd926409dcdd67', 'to_address_label': None, 'address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48', 'block_hash': '0xc470c09b3c36580ba630ae5f229dbc88ed12c7bf7635c015dcdb5e371777de0e', 'block_number': '21233718', 'block_timestamp': '2024-11-21T04:27:47.000Z', 'transaction_hash': '0x63832b6ab7276db9f16c6628b3d8e0767c0ca834c432d61f412dc0b4c32af803', 'transaction_index': 148, 'log_index': 368, 'value': '147415636327', 'possible_spam': False, 'value_decimal': '147415.636327', 'verified_contract': True, 'security_score': 93}, {'token_name': 'USD Coin', 'token_symbol': 'USDC', 'token_logo': 'https://logo.moralis.io/0x1_0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48_7f342f7e169e45d4948987ccb93c62a8.png', 'token_decimals': '6', 'from_address_entity': None, 'from_address_entity_logo': None, 'from_address': '0xfaa0768bde629806739c3a4620656c5d26f44ef2', 'from_address_label': None, 'to_address_entity': None, 'to_address_entity_logo': None, 'to_address': '0x39041f1b366fe33f9a5a79de5120f2aee2577ebc', 'to_address_label': None, 'address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48', 'block_hash': '0xc470c09b3c36580ba630ae5f229dbc88ed12c7bf7635c015dcdb5e371777de0e', 'block_number': '21233718', 'block_timestamp': '2024-11-21T04:27:47.000Z', 'transaction_hash': '0x63832b6ab7276db9f16c6628b3d8e0767c0ca834c432d61f412dc0b4c32af803', 'transaction_index': 148, 'log_index': 366, 'value': '369462747', 'possible_spam': False, 'value_decimal': '369.462747', 'verified_contract': True, 'security_score': 93}, {'token_name': 'USD Coin', 'token_symbol': 'USDC', 'token_logo': 'https://logo.moralis.io/0x1_0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48_7f342f7e169e45d4948987ccb93c62a8.png', 'token_decimals': '6', 'from_address_entity': None, 'from_address_entity_logo': None, 'from_address': '0xfaa0768bde629806739c3a4620656c5d26f44ef2', 'from_address_label': None, 'to_address_entity': None, 'to_address_entity_logo': None, 'to_address': '0x55877bd7f2ee37bde55ca4b271a3631f3a7ef121', 'to_address_label': None, 'address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48', 'block_hash': '0x1f4ffc498192cc2cc41cb9f194133ef57c9b0563830308c26c5db485694d9368', 'block_number': '21233715', 'block_timestamp': '2024-11-21T04:27:11.000Z', 'transaction_hash': '0xfb025e3598aacf783954a7d66bad4060c0fda9d29a4f53ecb6372a3a7e67b650', 'transaction_index': 90, 'log_index': 261, 'value': '100000000000', 'possible_spam': False, 'value_decimal': '100000', 'verified_contract': True, 'security_score': 93}, {'token_name': 'USD Coin', 'token_symbol': 'USDC', 'token_logo': 'https://logo.moralis.io/0x1_0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48_7f342f7e169e45d4948987ccb93c62a8.png', 'token_decimals': '6', 'from_address_entity': None, 'from_address_entity_logo': None, 'from_address': '0xfaa0768bde629806739c3a4620656c5d26f44ef2', 'from_address_label': None, 'to_address_entity': None, 'to_address_entity_logo': None, 'to_address': '0x55877bd7f2ee37bde55ca4b271a3631f3a7ef121', 'to_address_label': None, 'address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48', 'block_hash': '0xb4a598e4012b3bca551be2d83c7e0fae3522e0bc692f7382029fa92caa240564', 'block_number': '21233709', 'block_timestamp': '2024-11-2 ...

# %%
from scripts.features import extract_compound_features

features_df = extract_compound_features()
features_df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from scripts.features import extract_compound_features
#       3 features_df = extract_compound_features()
#       4 features_df.head()
#
# ModuleNotFoundError: No module named 'scripts.features'
